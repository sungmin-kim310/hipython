# %% [markdown]
# # 안녕하세요

# %%
print("안녕")
"반가워"
# Out:
# 안녕
# '반가워'

# %%
# 3+3
2-1
5-4
#안녕하세요
# Out:
# 1

# %%
"""안녕하세요

반갑습니다"""
# Out:
# '안녕하세요\n\n반갑습니다'

# %%
def calculate_sum(a, b):
    result = a + b   # 들여쓰기된 코드 블록
    return result    # 같은 레벨의 들여쓰기

result = calculate_sum(3,-4)

if result > 0:
    print("양수입니다") # if문 내부의 들여쓰기된 코드
print(result)
# Out:
# -1

# %%
def calculate_sum(a, b):
    result = a + b   # 들여쓰기된 코드 블록
    return result    # 같은 레벨의 들여쓰기

result = calculate_sum(3,4)

if result > 0:
    print(result)
    print("양수입니다") # if문 내부의 들여쓰기된 코드
# Out:
# 7
# 양수입니다

# %% [markdown]
# # jupyter notebook

# %% [markdown]
# ## 안녕 2

# %% [markdown]
# ### 안녕 3

# %% [markdown]
# #### 안녕 4

# %% [markdown]
# ##### 안녕 5

# %% [markdown]
# ## 리스트

# %% [markdown]
# * 하나

# %% [markdown]
# * 둘

# %% [markdown]
# * 셋

# %% [markdown]
# 1. 하나

# %% [markdown]
# 2. 둘

# %% [markdown]
# 3. 셋

# %% [markdown]
# * 바깥쪽 리스트
#     - 2번째 리스트
#     - 3번째 리스트

# %% [markdown]
# * 바깥쪽 리스트
#     * 2번째 리스트

# %% [markdown]
# * 바깥쪽 리스트
#     * 리스트 1
#         * 아아아

# %% [markdown]
# * 아아아
#   * 아아아아아
#     * 아아아아아아아

# %% [markdown]
# 1. 안녕
# 2. 반가워

# %% [markdown]
# |번호|이름|
# | :----- | :----- |
# |1|개구리|
# |2|도마뱀|

# %% [markdown]
# ![이쁜꽃](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS1HdZvGb-kaxHbP_vNHswVgVjsIgo21DSOPA&s)

# %% [markdown]
# ![image.png](attachment:21a34c59-8e69-4605-bf0b-4fc473a418bc.png)
