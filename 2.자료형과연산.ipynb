# %% [markdown]
# # - 기본자료형 : 정수형, 실수형 > 숫자형, 문자형, 부울 형 boolean
# # - 복합자료형 : list, tuple, dictionary, set

# %% [markdown]
# ## 기본자료형

# %% [markdown]
# ### int 정수형

# %%
20, type(20)
# Out:
# (20, int)

# %%
a = 20 #10진수
a
# Out:
# 20

# %%
a = 0b0101 # 2**3*0+2**2*1+2**1*0+2**0*1
a
# Out:
# 5

# %%
a = 0o10 #0b1000, 0x16d
a
# Out:
# 8

# %%
a = 0x16d
a
# Out:
# 365

# %%
### float

# %%
b=3.14
type(b), b
# Out:
# (float, 3.14)

# %% [markdown]
# ### 지수의 표기
# 10e2

# %%
a = 10e2
a
# Out:
# 1000.0

# %%
a = 10e-2 # 10*10**-2
a
# Out:
# 0.1

# %%
3.1415e9 # 3.1415 * 10**9
# Out:
# 3141500000.0

# %% [markdown]
# ### boolean 부울형
#
# true == 1 == 참, false == 0 == 거짓 예약어

# %%
a = 10
a = 3.14
a = 3.14e5
a = True
b = False
a,b
# Out:
# (True, False)

# %%
type(a), type(b)
# Out:
# (bool, bool)

# %%
### 논리연산, 비교연산

# %%
a == 0 #== 같다 연산자(vs 할당연산자)
# Out:
# False

# %%
a == 1
# Out:
# True

# %%
a == True
# Out:
# True

# %%
a == true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 a == true
#
# NameError: name 'true' is not defined

# %%
a == "true"
# Out:
# False

# %%
b = 1
a and b, a, b
# Out:
# (1, True, 1)

# %% [markdown]
# # and : a,b 모두 참(1)일때 1
# # or : a,b 둘중 1개만 참(1)일 때1
# # not : 반대 참(1)이면 거짓(0), 거짓(0)이면 참(1)

# %%
bool('50') # 0이면 false 이외는 true
# Out:
# True

# %%
a=2
b=3

# %%
#사칙연산
a+b, a-b, a*b, a/b, a//b, a%b
# Out:
# (5, -1, 6, 0.6666666666666666, 0, 2)

# %%
#비교연산
3 == 2, 3 != 2, 3 > 2, 3 >= 2
# Out:
# (False, True, True, True)

# %%
#대입연산 = += -=
a=10
a+=10
a
# Out:
# 20

# %%
a=10
a-=2
a
# Out:
# 8

# %% [markdown]
# # 문자열 str

# %%
first_name = 'sm'
last_name = 'kim'
first_name + last_name
# Out:
# 'smkim'

# %%
last_name == 'Kim'
# Out:
# False

# %%
last_name == 'Kim'.lower() ##소문자 lower(), 대문자 upper()
# Out:
# True

# %%
last_name.capitalize == 'kim' #첫글자만 대문자 capitalize
# Out:
# False

# %%
text = """Pinkfong
(상어 가족)
아기 상어 뚜루루 뚜루
귀여운 뚜루루 뚜루
바닷속 뚜루루 뚜루
아기 상어!
엄마 상어 뚜루루 뚜루
어여쁜 뚜루루 뚜루
바닷속 뚜루루 뚜루
엄마 상어!
아빠 상어 뚜루루 뚜루
힘이 센 뚜루루 뚜루
바닷속 뚜루루 뚜루
아빠 상어!
할머니 상어 (뚜루루 뚜루)
자상한 (뚜루루 뚜루)
바닷속 뚜루루 뚜루
할머니 상어!
할아버지 상어 (뚜루루 뚜루)
멋있는 (뚜루루 뚜루)
바닷속 뚜루루 뚜루
할아버지 상어!
우리는 뚜루루 뚜루
바다의 뚜루루 뚜루
사냥꾼 뚜루루 뚜루
상어 가족!
상어다 뚜루루 뚜루
도망쳐 뚜루루 뚜루
도망쳐 뚜루루 뚜루
숨자! 으악!
살았다 뚜루루 뚜루
살았다 뚜루루 뚜루
오늘도 뚜루루 뚜루
살았다 휴!
신난다 (뚜루루 뚜루)
신난다 (뚜루루 뚜루)
춤을 춰 뚜루루 뚜루
노래 끝! 오예!"""
print(text.count("뚜루루 뚜루"))
# Out:
# 27

# %%
text[0:10] #시작인덱스:끝인덱스
# Out:
# 'Pinkfong\n('

# %% [markdown]
# 주민등록번호의 생년월일 부분만 출력해보세요

# %%
주민등록번호 = "991122-1919191"
주민등록번호[0:6]
# Out:
# '991122'

# %%
주민등록번호.split('-')[0]
# Out:
# '939393'

# %%
if 주민등록번호[0:2] == '99' :
    print(주민등록번호[2:4]+"월")
else:
    print(주민등록번호[4:6]+"일")
# Out:
# 11월

# %%
if 주민등록번호[0:2] == "94":
    print(주민등록번호[2:4] + "월")
else:
    print(주민등록번호[4:6] + "일")
# Out:
# 22일

# %%
주민등록번호[-2:]
# Out:
# '91'

# %%
주민등록번호.split("-")[1][0]
# Out:
# '1'

# %%
신주민등록번호 = 주민등록번호.replace('1','3')
신주민등록번호
# Out:
# '993322-3939393'

# %%
주민등록번호_신 = 주민등록번호[:7] + '3' + 주민등록번호[8:]
주민등록번호_신
# Out:
# '991122-3919191'

# %% [markdown]
# ## 인덱싱과 슬라이싱

# %%
text = "Python"
print(text[0], text[-1]) #indexing
      
print(text[0:3])   # "Pyt"
print(text[2:])    # "thon"
print(text[:4])    # "Pyth"
print(text[-3:])   # "hon"
print(text[::2])   #??
# Out:
# P n
# Pyt
# thon
# Pyth
# hon
# Pto

# %%
'a'.encode('utf-8')
dec_value = 'a'.encode('utf-16')
dec_value
# Out:
# b'\xff\xfea\x00'

# %%
dec_value.decode('utf-16')
# Out:
# 'a'

# %%
# format()
#test_str = ' 99.99 dollars are worth us $100 입니다.'
test_str = ' {0:.4f} {1:s} are worth us {2:d} 입니다.' #템플릿
test_str.format(99.99, "dollars",100)
# Out:
# ' 99.9900 dollars are worth us 100 입니다.'

# %%
num1 = 99
num2 = 100
str1 = 'dollars'
test_str = f'{num1:.4f} {str1:s} are worth us ${num2:d} 입니다.'
test_str
# Out:
# '99.0000 dollars are worth us $100 입니다.'

# %%
len(test_str)
# Out:
# 38

# %%
email = 'aaa@gmail.com'
email_1 = 'aaa@gmail.com '
email_2 = ' aaa@gmail.com'
len(email), len(email_1), len(email_2)
# Out:
# (13, 14, 14)

# %%
len(email_1.strip()), len(email_2.strip()) #strip은 앞뒤 공백을 없애줌.
# Out:
# (13, 13)

# %%
text.find('뚜루루')
# Out:
# 23

# %%
text.rfind('뚜루루') #index
# Out:
# 394

# %%
text[394:397]
# Out:
# '뚜루루'

# %% [markdown]
# # 문자열
#
# 1. 인덱싱, 슬라이싱, 멤버쉽
# 2. 문자열은 immutable "불변", 대소문자 구분함
# 3. 문자열은 코드를 지정 인코딩, 디코딩, 유니코드(이모지), 한글
# 4. 문자열 +, * 사용 가능
# 5. 공백처리, 형식처리 등을 해야한다.

# %%
import re
text = "파이썬 문자열   처리"
#text.split(" ") = ['파이썬', '문자열', '', '', '처리']
re.sub(r"\s+"," ", text) # \s 스페이스, r은 표현식?
# Out:
# '파이썬 문자열 처리'

# %%
tel_no = '010-1234-5678'
re.sub(r"\D", "", tel_no)
# Out:
# '01012345678'

# %%
# 생성자 creator, function 함수
int(1)     #1
float(1)   #1.1
str()      #" ", ' ', """ """. ''' '''

list()     #[ ]
tuple()    #( )
dict()     #{ }
set()      #{ }

# %%
# 사칙연산자, 비교연산자, 논리연산자, 대입연산자, 기타...
+, -, *, /, %, //
>, <, ==, !=
and, or, not, &,|, !
=, +=, -=, *=, /=
in(맴버쉽)

# %%
# 타입별 메소드 제공
dir(1), dir('a')
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
dir([1,2])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
list_obj.append()
