# %% [markdown]
# # 1~10

# %%
print('Hello World')
# Out:
# Hello World

# %%
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
print('신씨가 소리질렀다. "도둑이야".')
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %%
print(r"C:\Windows")
# Out:
# C:\Windows

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.") #\n : 줄바꿈, \t 탭(크게 띄어쓰기)
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
print("naver;kakao;sk;samsung") #print("naver","kakao","sk","samsung",sep=";")
# Out:
# naver;kakao;sk;samsung

# %%
print("naver/kakao/sk/samsung") ##print("naver","kakao","sk","samsung",sep="/")
# Out:
# naver/kakao/sk/samsung

# %%
print("first", end="");print("second")
# Out:
# firstsecond

# %%
print(5/3)
# Out:
# 1.6666666666666667

# %% [markdown]
# # 11 ~ 20

# %%
price = 50000
quantity = 10
total_value = price * quantity
print(total_value)
# Out:
# 500000

# %%
total_value = 298000000000000
price = 50000
PER = 15.79
print(total_value, type(total_value))
print(price, type(price))
print(PER, type(PER))
# Out:
# 298000000000000 <class 'int'>
# 50000 <class 'int'>
# 15.79 <class 'float'>

# %%
s = "hello"
t = "python"
print(s+"! "+t)
# Out:
# hello! python

# %%
2+2*3
# Out:
# 8
