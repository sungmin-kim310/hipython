# %% [markdown]
# # 중심 경향성

# %% [markdown]
# # 평균

# %%
import numpy as np

data = [10, 20, 30, 40, 50]
mean_value = np.mean(data)
print(mean_value)
# Out:
# 30.0

# %%
import numpy as np

prices = np.array([5000, 9000])   # 상품 가격
counts = np.array([8, 2])         # 구매 수량

average_price = np.average(prices, weights=counts)
print(average_price)
# Out:
# 5800.0

# %%
data = {
    '점수' : [97, 94, 92, 91, 90, 89, 78, 60],
    '

# %%
total_people = sum(data['인원수'])

print(f

# %%
import numpy as np

# 초기 매출
initial = 100

# 시나리오 적용
step1 = initial * 2.0      # +100%
step2 = step1 * 0.5        # -50%
final = step2

print(f"초기: {initial}만원")
print(f"1차 후: {step1}만원")
print(f"최종: {final}만원")
print(f"\n실제 변화: {((final/initial - 1) * 100):.1f}%")

# 산술평균
arithmetic = (100 + (-50)) / 2
print(f"산술평균: {arithmetic:.1f}%")

# 기하평균
geometric = (np.sqrt(2.0 * 0.5) - 1) * 100
print(f"기하평균: {geometric:.1f}%")
# Out:
# 초기: 100만원
# 1차 후: 200.0만원
# 최종: 100.0만원
#
# 실제 변화: 0.0%
# 산술평균: 25.0%
# 기하평균: 0.0%

# %%
import numpy as np
from scipy import stats

# 1. 데이터: 갈 때 100km/h, 올 때 50km/h
speeds = [100, 50]

# 2. 평균 계산 비교
# A. 산술평균 (오답)
arithmetic = np.mean(speeds)

# B. 조화평균 (정답)
harmonic = stats.hmean(speeds)

# 3. 결과 리포트
print(f"데이터: {speeds}")
print("-" * 35)
print(f"1. [❌ 오류] 산술평균: {arithmetic:.2f} km/h")
print("-" * 35)
print(f"2. [✅ 정답] 조화평균: {harmonic:.2f} km/h")
print(f"   >> 해석: '느린 구간(50) 때문에 전체 효율이 급감했습니다.'")
print(f"   >> 실제 물리적 평균 속도는 66.67km/h가 맞습니다.")
# Out:
# 데이터: [100, 50]
# -----------------------------------
# 1. [❌ 오류] 산술평균: 75.00 km/h
# -----------------------------------
# 2. [✅ 정답] 조화평균: 66.67 km/h
#    >> 해석: '느린 구간(50) 때문에 전체 효율이 급감했습니다.'
#    >> 실제 물리적 평균 속도는 66.67km/h가 맞습니다.

# %%
200/3
# Out:
# 66.66666666666667

# %%
import numpy as np

data = [10, 20, 30, 40, 50]
median_value = np.median(data)
print(median_value)  # 30
# Out:
# 30.0

# %%
import numpy as np

scores = [65, 75, 80, 85, 95]

# 백분위수 계산
p25 = np.percentile(scores, 25)  # Q1
p50 = np.percentile(scores, 50)  # 중앙값
p75 = np.percentile(scores, 75)  # Q3

print(f"25번째 백분위수: {p25}")  # 75.0
print(f"50번째 백분위수(중앙값): {p50}")  # 80.0
print(f"75번째 백분위수: {p75}")  # 85.0
print(f"사분위간 범위(IQR): {p75 - p25}")  # 10.0
# Out:
# 25번째 백분위수: 75.0
# 50번째 백분위수(중앙값): 80.0
# 75번째 백분위수: 85.0
# 사분위간 범위(IQR): 10.0

# %%
scores = [70, 80, 80, 90, 60, 80, 70]
counts = {}

for x in scores:
    if x in counts:
        counts[x] += 1
    else:
        counts[x] = 1

counts
# 결과
{70: 2, 80: 3, 90: 1, 60: 1}
#최빈값은 ? 80
# Out:
# {70: 2, 80: 3, 90: 1, 60: 1}

# %%
#함수로 구하기
mode = max(counts, key=counts.get)
mode
# Out:
# 80

# %%
import pandas as pd
score_data = pd.Series(scores) # 열이 하나인 객체?
score_data.mode()
# Out:
# 0    80
# dtype: int64

# %%
pd.DataFrame(scores)
# Out:
#     0
# 0  70
# 1  80
# 2  80
# 3  90
# 4  60
# 5  80
# 6  70

# %%
#평균은 같지만, 느낌이 다른 데이터

A = [50, 50, 50, 50, 50]
B = [10, 30, 50, 70, 90]
avg1 = sum(A) / len(A)  # 50
avg2 = sum(B) / len(B)  # 50
avg1, avg2
# Out:
# (50.0, 50.0)

# %%
#평균 기준 변동성 계산
mean = sum(B) / len(B)  # 50
[x - mean for x in B]
# Out:
# [-40.0, -20.0, 0.0, 20.0, 40.0]

# %% [markdown]
# # 변동성 - 범위

# %%
data = [10, 20, 30, 40, 50]
range_value = max(data) - min(data)
print(range_value)  # 40
# Out:
# 40

# %%
data1 = [50, 50, 50, 50, 50]
data2 = [10, 30, 50, 70, 90]
data3 = [30, 40, 50, 60, 70]

np.mean(data1), np.mean(data2), np.mean(data3)
# Out:
# (np.float64(50.0), np.float64(50.0), np.float64(50.0))

# %%
data2_range = max(data2) - min(data2)
data3_range = max(data3) - min(data3)
data2_range, data3_range
# Out:
# (80, 40)

# %%
import numpy as np

data = [10, 20, 30, 40, 50]
variance_value = np.var(data)
print(variance_value)  # 200.0
# Out:
# 200.0

# %%
np.var(data2), np.var(data3)
# Out:
# (np.float64(800.0), np.float64(200.0))

# %%
np.std(data2), np.std(data3)
# Out:
# (np.float64(28.284271247461902), np.float64(14.142135623730951))

# %% [markdown]
# # 변동성 - 빈도분포표

# %%
data = [
    [47, 10, 31, 25, 20],
    [2, 11, 31, 25, 21],
    [44, 14, 15, 26, 21],
    [41, 14, 16, 26, 21],
    [7, 30, 17, 27, 24],
    [6, 30, 16, 29, 24],
    [35, 32, 15, 29, 23],
    [38, 33, 19, 28, 20],
    [35, 34, 18, 29, 21],
    [36, 32, 16, 27, 20],
]

# %%
df = pd.DataFrame(data,columns = ['A','B','C','D','E'])
df
# Out:
#     A   B   C   D   E
# 0  47  10  31  25  20
# 1   2  11  31  25  21
# 2  44  14  15  26  21
# 3  41  14  16  26  21
# 4   7  30  17  27  24
# 5   6  30  16  29  24
# 6  35  32  15  29  23
# 7  38  33  19  28  20
# 8  35  34  18  29  21
# 9  36  32  16  27  20

# %%
import matplotlib.pyplot as plt
plt.hist(df)
# Out:
# (array([[ 2.,  1.,  0.,  0.,  0.,  0.,  0.,  3.,  2.,  2.],
#         [ 0.,  1.,  3.,  0.,  0.,  0.,  5.,  1.,  0.,  0.],
#         [ 0.,  0.,  2.,  6.,  0.,  0.,  2.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0.,  0.,  7.,  3.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0., 10.,  0.,  0.,  0.,  0.,  0.]]),
#  array([ 2. ,  6.5, 11. , 15.5, 20. , 24.5, 29. , 33.5, 38. , 42.5, 47. ]),
#  <a list of 5 BarContainer objects>)

# %%
plt.hist(df['A'])
# Out:
# (array([2., 1., 0., 0., 0., 0., 0., 3., 2., 2.]),
#  array([ 2. ,  6.5, 11. , 15.5, 20. , 24.5, 29. , 33.5, 38. , 42.5, 47. ]),
#  <BarContainer object of 10 artists>)

# %%
for col in df.columns:
    plt.hist(df[col])
    plt.title(col)
    plt.show()

# %%
## 첨도

양의 첨도: 정규분포보다 값의 크기만큼 뾰족하다. 꼬리가 두껍다(길다)
음의 첨도: 정규분포보다 값의 크기만큼 눌려있다. 꼬리가 얇다(짧다)

# %%
from scipy.stats import kurtosis
positive_kurtosis = [
    50, 50, 50, 50, 50,
    48, 52,
    35, 65
]
negative_kurtosis = [
    42, 44, 46, 48,
    52, 54, 56, 58
]
pos_kurtosis_value = kurtosis(positive_kurtosis )
neg_kurtosis_value = kurtosis(negative_kurtosis )

print(pos_kurtosis_value, neg_kurtosis_value )
# Out:
# 1.345540702885148 -1.4266666666666667

# %%
plt.hist(positive_kurtosis)
# Out:
# (array([1., 0., 0., 0., 1., 6., 0., 0., 0., 1.]),
#  array([35., 38., 41., 44., 47., 50., 53., 56., 59., 62., 65.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(negative_kurtosis)
# Out:
# (array([1., 1., 1., 1., 0., 0., 1., 1., 1., 1.]),
#  array([42. , 43.6, 45.2, 46.8, 48.4, 50. , 51.6, 53.2, 54.8, 56.4, 58. ]),
#  <BarContainer object of 10 artists>)

# %%
from scipy.stats import skew

data = [10, 20, 30, 40, 100]  # 오른쪽으로 치우친 데이터
skew_value = skew(data)
print(skew_value)  # 양수 (오른쪽 꼬리)
# Out:
# 1.1384199576606167

# %% [markdown]
# # 그래프로 표현하기

# %%
import matplotlib.pyplot as plt

# ==========================================
# 1. Data preparation (Categorical data)
# ==========================================
# Scenario: Number of completed projects by team
teams = ['Strategy', 'Sales', 'Marketing', 'HR', 'IT']
counts = [12, 25, 18, 8, 30]

# ==========================================
# 2. Create bar chart
# ==========================================
plt.figure(figsize=(10, 6))

plt.bar(teams, counts, width=0.6) # x축, y축 순으로 데이터 지정

plt.title('Team Performance: Projects Completed', fontsize=16, pad=15)
plt.xlabel('Department', fontsize=12)
plt.ylabel('Number of Projects', fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
#그룹막대
import numpy as np

teams = ['Strategy', 'Sales', 'Marketing', 'HR', 'IT']
score_2025 = [12, 25, 18, 8, 30]
score_2024 = [10, 20, 15, 8, 35]

x = np.arange(len(teams))   # 팀 개수만큼 위치 생성
width = 0.35                # 막대 너비

plt.bar(x - width/2, score_2025, width, label='2025')
plt.bar(x + width/2, score_2024, width, label='2024')

plt.xticks(x, teams)        # x축 라벨을 팀 이름으로
plt.legend()

# %%
# 원도표
# 1. 데이터 준비 (시장 점유율 상황)
labels = ['Company A', 'Company B', 'Company C', 'Others']
sizes = [45, 30, 15, 10]  # 합이 100이 되게 하는 것이 일반적

colors = ['#4c72b0', '#55a868', '#c44e52', '#8172b3'] # 색상 지정

plt.figure(figsize=(6, 6))

# 2. 원도표 그리기
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors)

plt.title('Market Share 2024')
plt.show()

# %%
plt.pie(sizes, labels=labels, autopct='%1.1f%%', wedgeprops={'width' : 0.3})
# Out:
# ([<matplotlib.patches.Wedge at 0x22ba682eaa0>,
#   <matplotlib.patches.Wedge at 0x22ba678dc00>,
#   <matplotlib.patches.Wedge at 0x22ba682f8b0>,
#   <matplotlib.patches.Wedge at 0x22ba68900a0>],
#  [Text(0.17207793356064993, 1.0864571711675968, 'Company A'),
#   Text(-0.8899184718302892, -0.6465640830538323, 'Company B'),
#   Text(0.4993897495105265, -0.9801070748055101, 'Company C'),
#   Text(1.0461621838648125, -0.339918644753721, 'Others')],
#  [Text(0.09386069103308177, 0.5926130024550527, '45.0%'),
#   Text(-0.485410075543794, -0.352671318029363, '30.0%'),
#   Text(0.2723944088239235, -0.5346038589848237, '15.0%'),
#   Text(0.5706339184717159, -0.185410169865666, '10.0%')])

# %%
#!pip install yfinance
# Out:
# Collecting yfinance
#   Using cached yfinance-1.0-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (2.2.5)
# Requirement already satisfied: requests>=2.31 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Using cached frozendict-2.4.7-cp310-cp310-win_amd64.whl.metadata (24 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Using cached peewee-3.19.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from yfinance) (4.14.2)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance)
#   Using cached curl_cffi-0.13.0-cp39-abi3-win_amd64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance)
#   Downloading protobuf-6.33.3-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance)
#   Downloading websockets-16.0-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from requests>=2.31->yfinance) (2.6.3)
# Downloading yfinance-1.0-py2.py3-none-any.whl (127 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.6 MB 226.8 kB/s eta 0:00:05
#    ------------ --------------------------- 0.5/1.6 MB 226.8 kB/s eta 0:00:05
#    ------------ --------------------------- 0.5/1.6 MB 226.8 kB/s eta 0:00:05
#    ------------ --------------------------- 0.5/1.6 MB 226.8 kB/s eta 0:00:05
#    ------------ --------------------------- 0.5/1.6 MB 226.8 kB/s eta 0:00:05
#    ------------------- -------------------- 0.8/1.6 MB 229.8 kB/s eta 0:00:04
#    ------------------- -------------------- 0.8/1.6 MB 229.8 kB/s eta 0:00:04
#    ------------------- -------------------- 0.8/1.6 MB 229.8 kB/s eta 0:00:04
#    ------------------- -------------------- 0.8/1.6 MB 229.8 kB/s eta 0:00:04
#    ------------------- -------------------- 0.8/1.6 MB 229.8 kB/s eta 0:00:04
#    ------------------- -------------------- 0.8/1.6 MB 229.8 kB/s eta 0:00:04
#    ------------------------- -------------- 1.0/1.6 MB 225.7 kB/s eta 0:00:03
#    -------------------------------- ------- 1.3/1.6 MB 289.3 kB/s eta 0:00:02
#    -------------------------------- ------- 1.3/1.6 MB 289.3 kB/s eta 0:00:02
#    -------------------------------- ------- 1.3/1.6 MB 289.3 kB/s eta 0:00:02
#    -------------------------------- ------- 1.3/1.6 MB 289.3 kB/s eta 0:00:02
#    -------------------------------- ------- 1.3/1.6 MB 289.3 kB/s eta 0:00:02
#    -------------------------------- ------- 1.3/1.6 MB 289.3 kB/s eta 0:00:02
#    -------------------------------------- - 1.6/1.6 MB 258.9 kB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 253.1 kB/s  0:00:05
# Downloading frozendict-2.4.7-cp310-cp310-win_amd64.whl (37 kB)
# Downloading peewee-3.19.0-py3-none-any.whl (411 kB)
# Downloading protobuf-6.33.3-cp310-abi3-win_amd64.whl (436 kB)
# Downloading websockets-16.0-cp310-cp310-win_amd64.whl (178 kB)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (pyproject.toml): started
#   Building wheel for multitasking (pyproject.toml): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15703 sha256=4958e683e09a0e4e5f9f4ac85e33b1abc6b7e56a47f811e386218f328f063eeb
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\e9\25\85\25d2e1cfc0ece64b930b16972f7e4cc3599c43b531f1eba06d
# Successfully built multitasking
# Installing collected packages: peewee, multitasking, websockets, protobuf, frozendict, curl_cffi, yfinance
#
#    ---------------------------------------- 0/7 [peewee]
#    ---------------------------------------- 0/7 [peewee]
#    ---------------------------------------- 0/7 [peewee]
#    ---------------------------------------- 0/7 [peewee]
#    ---------------------------------------- 0/7 [peewee]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------- ---------------------------- 2/7 [websockets]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ----------------- ---------------------- 3/7 [protobuf]
#    ---------------------- ----------------- 4/7 [frozendict]
#    ---------------------------- ----------- 5/7 [curl_cffi]
#    ---------------------------- ----------- 5/7 [curl_cffi]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------- ----- 6/7 [yfinance]
#    ---------------------------------------- 7/7 [yfinance]
#
# Successfully installed curl_cffi-0.13.0 frozendict-2.4.7 multitasking-0.0.12 peewee-3.19.0 protobuf-6.33.3 websockets-16.0 yfinance-1.0

# %%
import yfinance as yf

# %%
ticker = '005930.KS'
data = yf.download(ticker, period = '1y')
type(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# pandas.core.frame.DataFrame

# %%
import matplotlib.pyplot as plt
ss_ticker = '005930.KS' #삼성전자

df = yf.download(ticker, start='2024-01-01')
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Close'])
plt.xlabel('Date')
plt.ylabel('Price (KRW)')
plt.grid(True, linestyle='--', alpha=0.5) # 격자선 (가독성 UP)
plt.legend()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20068\4104423320.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
data.head()
# Out:
# Price              Close          High           Low          Open    Volume
# Ticker         005930.KS     005930.KS     005930.KS     005930.KS 005930.KS
# Date
# 2025-01-13  53215.187500  54100.467884  53215.187500  53707.009935  16868600
# 2025-01-14  53018.457031  53707.008421  52821.728063  53313.550484  17465926
# 2025-01-15  52821.726562  53805.371377  52624.997600  53215.184488  18625025
# 2025-01-16  53411.914062  54100.465441  53215.185097  53313.549580  18627298
# 2025-01-17  52821.726562  53215.184488  52329.904155  52920.091044  18805344

# %%
data.tail()
# Out:
# Price          Close      High       Low      Open    Volume
# Ticker     005930.KS 005930.KS 005930.KS 005930.KS 005930.KS
# Date
# 2026-01-06  138900.0  139300.0  132700.0  135300.0  45321341
# 2026-01-07  141000.0  144400.0  137600.0  143500.0  46317413
# 2026-01-08  138800.0  144500.0  138300.0  138300.0  41449329
# 2026-01-09  139000.0  140700.0  135200.0  136000.0  29520566
# 2026-01-12  140300.0  142000.0  139300.0  141000.0   9969697

# %%
plt.figure(figsize=(12,5))
plt.plot(data.index, data['Close'])

# %% [markdown]
# # 히스토그램

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#랜덤한 1000개의 데이터 생성
data = np.random.normal(loc=50000, scale=15000, size = 1000)

# %%
len(data)
# Out:
# 1000

# %%
plt.hist(data)
# Out:
# (array([  9.,  22.,  56., 142., 203., 209., 190., 107.,  51.,  11.]),
#  array([ 3224.3694464 , 11932.13316462, 20639.89688284, 29347.66060107,
#         38055.42431929, 46763.18803751, 55470.95175574, 64178.71547396,
#         72886.47919218, 81594.24291041, 90302.00662863]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data,bins=30)
# Out:
# (array([ 2.,  3.,  4.,  3.,  5., 14., 12., 14., 30., 44., 50., 48., 55.,
#         73., 75., 82., 58., 69., 70., 60., 60., 38., 32., 37., 27., 12.,
#         12.,  3.,  6.,  2.]),
#  array([ 3224.3694464 ,  6126.95735247,  9029.54525855, 11932.13316462,
#         14834.7210707 , 17737.30897677, 20639.89688284, 23542.48478892,
#         26445.07269499, 29347.66060107, 32250.24850714, 35152.83641322,
#         38055.42431929, 40958.01222537, 43860.60013144, 46763.18803751,
#         49665.77594359, 52568.36384966, 55470.95175574, 58373.53966181,
#         61276.12756789, 64178.71547396, 67081.30338003, 69983.89128611,
#         72886.47919218, 75789.06709826, 78691.65500433, 81594.24291041,
#         84496.83081648, 87399.41872256, 90302.00662863]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(data,bins=100,density=True,alpha=0.6,edgecolor='white')
# Out:
# (array([1.14840048e-06, 1.14840048e-06, 0.00000000e+00, 1.14840048e-06,
#         0.00000000e+00, 2.29680095e-06, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 4.59360190e-06, 1.14840048e-06, 0.00000000e+00,
#         1.14840048e-06, 1.14840048e-06, 2.29680095e-06, 1.14840048e-06,
#         2.29680095e-06, 6.89040286e-06, 4.59360190e-06, 4.59360190e-06,
#         5.74200238e-06, 4.59360190e-06, 2.29680095e-06, 3.44520143e-06,
#         3.44520143e-06, 8.03880333e-06, 5.74200238e-06, 5.74200238e-06,
#         1.14840048e-05, 1.37808057e-05, 1.26324052e-05, 1.26324052e-05,
#         1.83744076e-05, 2.18196090e-05, 1.95228081e-05, 1.37808057e-05,
#         1.60776067e-05, 1.37808057e-05, 1.14840048e-05, 2.29680095e-05,
#         2.18196090e-05, 1.60776067e-05, 2.06712086e-05, 2.29680095e-05,
#         2.52648105e-05, 2.64132110e-05, 2.18196090e-05, 1.72260071e-05,
#         2.64132110e-05, 3.44520143e-05, 2.41164100e-05, 2.98584124e-05,
#         2.64132110e-05, 3.21552133e-05, 2.52648105e-05, 1.26324052e-05,
#         1.60776067e-05, 2.75616114e-05, 1.72260071e-05, 2.87100119e-05,
#         2.29680095e-05, 2.98584124e-05, 2.41164100e-05, 1.83744076e-05,
#         2.29680095e-05, 1.95228081e-05, 1.72260071e-05, 2.52648105e-05,
#         1.72260071e-05, 2.06712086e-05, 1.37808057e-05, 1.37808057e-05,
#         1.26324052e-05, 1.26324052e-05, 5.74200238e-06, 1.49292062e-05,
#         1.14840048e-05, 1.14840048e-05, 1.60776067e-05, 1.03356043e-05,
#         1.03356043e-05, 8.03880333e-06, 9.18720381e-06, 6.89040286e-06,
#         5.74200238e-06, 1.14840048e-06, 6.89040286e-06, 2.29680095e-06,
#         3.44520143e-06, 4.59360190e-06, 2.29680095e-06, 1.14840048e-06,
#         0.00000000e+00, 0.00000000e+00, 2.29680095e-06, 2.29680095e-06,
#         2.29680095e-06, 0.00000000e+00, 1.14840048e-06, 1.14840048e-06]),
#  array([ 3224.3694464 ,  4095.14581822,  4965.92219004,  5836.69856187,
#          6707.47493369,  7578.25130551,  8449.02767733,  9319.80404915,
#         10190.58042098, 11061.3567928 , 11932.13316462, 12802.90953644,
#         13673.68590827, 14544.46228009, 15415.23865191, 16286.01502373,
#         17156.79139556, 18027.56776738, 18898.3441392 , 19769.12051102,
#         20639.89688284, 21510.67325467, 22381.44962649, 23252.22599831,
#         24123.00237013, 24993.77874196, 25864.55511378, 26735.3314856 ,
#         27606.10785742, 28476.88422925, 29347.66060107, 30218.43697289,
#         31089.21334471, 31959.98971654, 32830.76608836, 33701.54246018,
#         34572.318832  , 35443.09520382, 36313.87157565, 37184.64794747,
#         38055.42431929, 38926.20069111, 39796.97706294, 40667.75343476,
#         41538.52980658, 42409.3061784 , 43280.08255023, 44150.85892205,
#         45021.63529387, 45892.41166569, 46763.18803751, 47633.96440934,
#         48504.74078116, 49375.51715298, 50246.2935248 , 51117.06989663,
#         51987.84626845, 52858.62264027, 53729.39901209, 54600.17538392,
#         55470.95175574, 56341.72812756, 57212.50449938, 58083.2808712 ,
#         58954.05724303, 59824.83361485, 60695.60998667, 61566.38635849,
#         62437.16273032, 63307.93910214, 64178.71547396, 65049.49184578,
#         65920.26821761, 66791.04458943, 67661.82096125, 68532.59733307,
#         69403.37370489, 70274.15007672, 71144.92644854, 72015.70282036,
#         72886.47919218, 73757.25556401, 74628.03193583, 75498.80830765,
#         76369.58467947, 77240.3610513 , 78111.13742312, 78981.91379494,
#         79852.69016676, 80723.46653858, 81594.24291041, 82465.01928223,
#         83335.79565405, 84206.57202587, 85077.3483977 , 85948.12476952,
#         86818.90114134, 87689.67751316, 88560.45388499, 89431.23025681,
#         90302.00662863]),
#  <BarContainer object of 100 artists>)

# %% [markdown]
# # 상자도표

# %%
np.random.seed(42)

sales = np.random.normal(50000, 10000, 100)
marketing = np.random.normal(55000, 12000, 100)
it = np.random.normal(60000, 15000, 100)

# %%
sales
# Out:
# array([54967.14153011, 48617.35698829, 56476.88538101, 65230.29856408,
#        47658.46625277, 47658.63043051, 65792.12815507, 57674.34729153,
#        45305.25614065, 55425.60043586, 45365.82307188, 45342.7024643 ,
#        52419.62271566, 30867.19755342, 32750.82167487, 44377.12470759,
#        39871.68879666, 53142.47332595, 40919.75924479, 35876.96298665,
#        64656.48768922, 47742.23699513, 50675.28204688, 35752.51813787,
#        44556.17275475, 51109.2258971 , 38490.06422578, 53756.98018346,
#        43993.61310081, 47083.06250207, 43982.93387771, 68522.78184509,
#        49865.02775262, 39422.89071044, 58225.44912103, 37791.56350029,
#        52088.63595005, 30403.2987612 , 36718.13951102, 51968.61235869,
#        57384.66579995, 51713.6828119 , 48843.51717612, 46988.96304411,
#        35214.78009633, 42801.55791605, 45393.6122904 , 60571.22226219,
#        53436.18289568, 32369.59844637, 53240.83969395, 46149.17719584,
#        43230.77999694, 56116.76288841, 60309.99522496, 59312.80119116,
#        41607.82476777, 46907.87624149, 53312.63431404, 59755.45127122,
#        45208.25762155, 48143.41023336, 38936.65025994, 38037.93375919,
#        58125.25822394, 63562.40028571, 49279.8987842 , 60035.32897892,
#        53616.36025048, 43548.80245395, 53613.95605508, 65380.36566466,
#        49641.7396089 , 65646.43655814, 23802.5489591 , 58219.02504375,
#        50870.47068238, 47009.92649534, 50917.60776536, 30124.31085399,
#        47803.28112162, 53571.12571512, 64778.94044742, 44817.29781726,
#        41915.06397107, 44982.42956415, 59154.02117702, 53287.5110966 ,
#        44702.39796233, 55132.67433113, 50970.77549348, 59686.44990533,
#        42979.46906123, 46723.37853402, 46078.91846868, 35364.85051868,
#        52961.20277065, 52610.5527218 , 50051.13456642, 47654.12866625])

# %%
sales
# Out:
# array([54967.14153011, 48617.35698829, 56476.88538101, 65230.29856408,
#        47658.46625277, 47658.63043051, 65792.12815507, 57674.34729153,
#        45305.25614065, 55425.60043586, 45365.82307188, 45342.7024643 ,
#        52419.62271566, 30867.19755342, 32750.82167487, 44377.12470759,
#        39871.68879666, 53142.47332595, 40919.75924479, 35876.96298665,
#        64656.48768922, 47742.23699513, 50675.28204688, 35752.51813787,
#        44556.17275475, 51109.2258971 , 38490.06422578, 53756.98018346,
#        43993.61310081, 47083.06250207, 43982.93387771, 68522.78184509,
#        49865.02775262, 39422.89071044, 58225.44912103, 37791.56350029,
#        52088.63595005, 30403.2987612 , 36718.13951102, 51968.61235869,
#        57384.66579995, 51713.6828119 , 48843.51717612, 46988.96304411,
#        35214.78009633, 42801.55791605, 45393.6122904 , 60571.22226219,
#        53436.18289568, 32369.59844637, 53240.83969395, 46149.17719584,
#        43230.77999694, 56116.76288841, 60309.99522496, 59312.80119116,
#        41607.82476777, 46907.87624149, 53312.63431404, 59755.45127122,
#        45208.25762155, 48143.41023336, 38936.65025994, 38037.93375919,
#        58125.25822394, 63562.40028571, 49279.8987842 , 60035.32897892,
#        53616.36025048, 43548.80245395, 53613.95605508, 65380.36566466,
#        49641.7396089 , 65646.43655814, 23802.5489591 , 58219.02504375,
#        50870.47068238, 47009.92649534, 50917.60776536, 30124.31085399,
#        47803.28112162, 53571.12571512, 64778.94044742, 44817.29781726,
#        41915.06397107, 44982.42956415, 59154.02117702, 53287.5110966 ,
#        44702.39796233, 55132.67433113, 50970.77549348, 59686.44990533,
#        42979.46906123, 46723.37853402, 46078.91846868, 35364.85051868,
#        52961.20277065, 52610.5527218 , 50051.13456642, 47654.12866625])

# %%
data = [sales, marketing, it] #numpy array의 리스트
labels = ['Sales', 'Marketing', 'IT']

# %%
plt.figure(figsize=(12,5))
plt.boxplot(data,labels=labels)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20068\3454745819.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data,labels=labels)
# {'whiskers': [<matplotlib.lines.Line2D at 0x22c9c453e80>,
#   <matplotlib.lines.Line2D at 0x22c9c47c0a0>,
#   <matplotlib.lines.Line2D at 0x22c9c47d2d0>,
#   <matplotlib.lines.Line2D at 0x22c9c47d5d0>,
#   <matplotlib.lines.Line2D at 0x22c9c47e7d0>,
#   <matplotlib.lines.Line2D at 0x22c9c47ead0>],
#  'caps': [<matplotlib.lines.Line2D at 0x22c9c47c3a0>,
#   <matplotlib.lines.Line2D at 0x22c9c47c6a0>,
#   <matplotlib.lines.Line2D at 0x22c9c47d8d0>,
#   <matplotlib.lines.Line2D at 0x22c9c47dbd0>,
#   <matplotlib.lines.Line2D at 0x22c9c47edd0>,
#   <matplotlib.lines.Line2D at 0x22c9c47f0d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x22c9c453b80>,
#   <matplotlib.lines.Line2D at 0x22c9c47cfd0>,
#   <matplotlib.lines.Line2D at 0x22c9c47e4d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x22c9c47c9a0>,
#   <matplotlib.lines.Line2D at 0x22c9c47ded0>,
#   <matplotlib.lines.Line2D at 0x22c9c47f3d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22c9c47cca0>,
#   <matplotlib.lines.Line2D at 0x22c9c47e1d0>,
#   <matplotlib.lines.Line2D at 0x22c9c47f6d0>],
#  'means': []}

# %% [markdown]
# #산점도

# %%
np.random.seed(42)
ad_spend = np.random.uniform(10, 100, 100)  # 광고비 (만원)
sales = 2.5 * ad_spend + np.random.normal(0, 15, 100)  # 매출액 (만원)

plt.figure(figsize=(10, 6))
plt.scatter(ad_spend, sales, alpha=0.6, color='#4c72b0', edgecolors='white')

plt.title('Relationship between Ad Spend and Sales (Scatter Plot)', fontsize=16)
plt.xlabel('Ad Spend (10K KRW)', fontsize=12)
plt.ylabel('Sales (10K KRW)', fontsize=12)
plt.grid(True, alpha=0.3)

# %%
z = np.polyfit(ad_spend, sales, 1)
p = np.poly1d(z)
plt.plot(ad_spend, p(ad_spend), "r--", alpha=0.8, label='Trend Line')
plt.legend()

plt.show()

# %%
plt.scatter(ad_spend, sales)
z = np.polyfit(ad_spend, sales, 1)
p = np.poly1d(z)
plt.plot(ad_spend, p(ad_spend), "r--", alpha=0.8, label='Trend Line')
plt.legend()

# %% [markdown]
# #상관분석 실습

# %%
import pandas as pd

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"

# 이 데이터셋의 표준 컬럼명 (직접 지정 필요)
column_names = [
    'CRIM',    # 1인당 범죄율
    'ZN',      # 25,000평방피트 초과 주거 지역 비율
    'INDUS',   # 비소매 상업 지역 비율
    'CHAS',    # 찰스강 더미 변수 (1: 강 경계, 0: 아님)
    'NOX',     # 일산화질소 농도
    'RM',      # 주택당 평균 방 개수
    'AGE',     # 1940년 이전에 건축된 소유 주택 비율
    'DIS',     # 5개 보스턴 고용 센터까지의 가중 거리
    'RAD',     # 방사형 고속도로 접근성 지수
    'TAX',     # 10,000달러당 재산세율
    'PTRATIO', # 학생-교사 비율
    'B',       # 흑인 인구 비율 (현재는 윤리적 이슈로 사용 지양 권고되기도 함)
    'LSTAT',   # 하위 계층 비율 (%)
    'MEDV'     # 본인 소유 주택 가격(중앙값) - 타겟 변수
]

# %%
df = pd.read_csv(url, sep='\s+', header=None, names=column_names)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
plt.scatter(df['RM'], df['MEDV'], alpha=0.6, color='#4c72b0', edgecolors='white')
z = np.polyfit(df['RM'], df['MEDV'], 1)
p = np.poly1d(z)
plt.plot(df['RM'], p(df['RM']), "r--", alpha=0.8, label='Trend Line')
plt.legend()

# %%
import numpy as np
from scipy import stats

# ==========================================
# 1단계: 데이터 수집 (가상 데이터 생성)
# ==========================================
np.random.seed(42)  # 결과 재현을 위한 시드 설정

# 상황: 통증 수치(0~100)가 얼마나 줄어들었는가? (수치가 높을수록 효과 좋음)
# 기존 진통제(A그룹): 평균 50만큼 감소, 표준편차 10, 환자 30명
group_old = np.random.normal(loc=50, scale=10, size=30)

# 신규 진통제(B그룹): 평균 55만큼 감소, 표준편차 10, 환자 30명
# (우리는 신규 약이 더 좋다고 가정하고 데이터를 만들었습니다)
group_new = np.random.normal(loc=55, scale=10, size=30)

print(f"[데이터 확인]")
print(f"기존 진통제 효과 평균: {group_old.mean():.2f}")
print(f"신규 진통제 효과 평균: {group_new.mean():.2f}")
print("-" * 30)
# Out:
# [데이터 확인]
# 기존 진통제 효과 평균: 48.12
# 신규 진통제 효과 평균: 53.79
# ------------------------------

# %%
# ==========================================
# 2단계: 가설 수립 및 검정 통계량 산출
# ==========================================
# H0: New <= Old (효과가 없거나 같다)
# H1: New > Old (신규 약이 더 우수하다) -> 'greater' 옵션 사용 (단측 검정)

# 독립 표본 T-검정 수행
t_stat, p_value = stats.ttest_ind(
    group_new,       # 신규 약 (대립가설의 주인공)
    group_old,       # 기존 약
    equal_var=False, # 등분산 가정 안 함 (Welch's t-test, 실무적으로 더 안전함)
    alternative='greater' # 중요: "더 크다(우수하다)"를 검증하므로 우측 검정
)

print(f"[검정 결과]")
print(f"T-statistic (차이의 크기): {t_stat:.4f}")
print(f"P-value (우연일 확률): {p_value:.4f}")
print("-" * 30)
# Out:
# [검정 결과]
# T-statistic (차이의 크기): 2.3981
# P-value (우연일 확률): 0.0099
# ------------------------------

# %%
# ==========================================
# 3단계: 최종 결정 (비즈니스 의사결정)
# ==========================================
alpha = 0.05  # 유의수준 (리스크 허용 범위 5%)

print(f"[최종 판단]")
if p_value < alpha:
    print(f"결과: 귀무가설 기각 (P-value {p_value:.4f} < {alpha})")
    print("해석: 신규 진통제의 효능이 통계적으로 유의미하게 우수합니다.")
    print("👉 Action: 신규 약 출시 승인 / 마케팅 포인트로 활용")
else:
    print(f"결과: 귀무가설 채택 (P-value {p_value:.4f} >= {alpha})")
    print("해석: 평균은 조금 높아 보일지 몰라도, 통계적으로 우수하다고 볼 수 없습니다 (우연일 가능성 높음).")
    print("👉 Action: 출시 보류 / 추가 임상 실험 필요")
# Out:
# [최종 판단]
# 결과: 귀무가설 기각 (P-value 0.0099 < 0.05)
# 해석: 신규 진통제의 효능이 통계적으로 유의미하게 우수합니다.
# 👉 Action: 신규 약 출시 승인 / 마케팅 포인트로 활용

# %%
H0 : 평균 몸무게는 70킬로이다.
H1 : 70킬로 아니다.(크거나, 작다 - 양측 검정)

# %%
import numpy as np
from scipy import stats

# %%
np.random.seed(123)
weight = np.random.uniform(40, 100, 100)
print(weight)
# Out:
# [81.78815114 57.1683601  53.61108721 73.07888614 83.16813819 65.38638761
#  98.8458519  81.08978432 68.85591409 63.52705109 60.59068097 83.74298244
#  66.31433468 43.5806738  63.88265532 84.27972434 50.94950383 50.52710537
#  71.89308243 71.90965523 78.06405751 90.96590764 83.46731949 76.66141064
#  83.34660295 59.37753483 61.70731934 53.69579385 57.62284278 77.85856743
#  45.5262964  66.02207036 65.8517658  69.62110586 65.54981742 58.73567338
#  65.58107842 93.60334979 96.64960109 70.11020055 77.43717711 46.9371037
#  59.03712891 64.88957272 91.97854947 55.02732192 68.98205586 99.13358714
#  71.16910716 76.77367155 47.23771996 89.58044803 76.1836077  72.70408039
#  60.56583003 58.24724734 65.02133266 80.87804595 92.52741051 70.62534025
#  80.15882698 75.15619315 77.49421013 80.48134306 90.54054626 44.9916993
#  85.82097049 54.61998247 51.65337763 74.34741745 45.742751   93.11960958
#  77.63493832 83.40498149 40.9677524  75.66591277 73.40711154 49.53757865
#  49.18423091 81.73177173 59.12598558 81.51821773 73.26299498 63.33703445
#  95.50794938 90.50019981 61.443854   42.61548783 58.2860844  63.89114092
#  82.29752983 99.72150892 61.35489194 85.75286883 75.59061499 81.50210792
#  49.06764714 63.93257756 54.45135386 60.60736084]

# %%
test_result, p_value = stats.ttest_1samp(weight, 70)

# %%
if p_value < 0.05 :
    print('귀무가설 기각')
    print('대한민국 남성의 평균 몸무게는 70kg이 아니다.')
else:
    print('귀무가설 채택')
    print('대한민국 남성의 평균 몸무게는 70kg이다.')
# Out:
# 귀무가설 채택
# 대한민국 남성의 평균 몸무게는 70kg이다.

# %%
np.mean(weight)
# Out:
# np.float64(70.08573280308887)

# %%
stats.ttest_1samp(weight, 70)
# Out:
# TtestResult(statistic=np.float64(0.05793922115108958), pvalue=np.float64(0.953913826658112), df=np.int64(99))

# %%
weight_new = np.random.normal(loc = 75, scale = 10, size = 100)
weight_new[:5]
# Out:
# array([95.8711336 , 76.6444123 , 86.50205543, 62.32647951, 76.8103513 ])

# %%
test_result, p_value = stats.ttest_1samp(weight_new, 70)

# %%
stats.ttest_1samp(weight_new, 70)
# Out:
# TtestResult(statistic=np.float64(5.429056292595452), pvalue=np.float64(4.043585489015101e-07), df=np.int64(99))

# %%
if p_value < 0.05 :
    print('귀무가설 기각')
    print('대한민국 남성의 평균 몸무게는 70kg이 아니다.')
else:
    print('귀무가설 채택')
    print('대한민국 남성의 평균 몸무게는 70kg이다.')
# Out:
# 귀무가설 기각
# 대한민국 남성의 평균 몸무게는 70kg이 아니다.

# %%
group_A = [78, 85, 82, 88, 76, 81, 79, 84, 82, 80]
group_B = [72, 75, 78, 74, 71, 77, 70, 76, 75, 73]

t_stat, p_value = stats.ttest_ind(group_A, group_B, equal_var=False)
print(f"t값 = {t_stat:.3f}, p값 = {p_value:.3f}")
# Out:
# t값 = 5.331, p값 = 0.000

# %%
# 대응 표본 t-검정 예제: 약물 투여 전후 혈압 비교
before = [120, 122, 143, 130, 135, 118, 127, 140, 132, 125]
after = [115, 117, 138, 125, 129, 112, 120, 135, 126, 119]

t_stat, p_value = stats.ttest_rel(before, after)
print(f"t값 = {t_stat:.3f}, p값 = {p_value:.3f}")
# Out:
# t값 = 25.327, p값 = 0.000

# %%
from scipy.stats import mannwhitneyu

# 두 그룹의 월 지출액 (단위: 만원)
high_income = [450, 520, 380, 600, 550, 480, 510, 490, 530, 470]
low_income = [250, 280, 230, 310, 270, 260, 240, 290, 255, 265]

u_stat, p_value = mannwhitneyu(high_income, low_income, alternative='two-sided')
print(f"U값 = {u_stat:.3f}, p값 = {p_value:.3f}")
# Out:
# U값 = 100.000, p값 = 0.000

# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.6-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from statsmodels) (2.2.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from statsmodels) (2.3.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\miniconda3\envs\stats\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Downloading statsmodels-0.14.6-cp310-cp310-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.6 MB 25.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.6 MB 28.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 22.1 MB/s  0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels
#
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    ---------------------------------------- 0/2 [patsy]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    -------------------- ------------------- 1/2 [statsmodels]
#    ---------------------------------------- 2/2 [statsmodels]
#
# Successfully installed patsy-1.0.2 statsmodels-0.14.6

# %%
from statsmodels.stats.proportion import proportions_ztest

# 예제: 두 광고의 클릭률 비교
# 광고 A: 100명 중 15명 클릭, 광고 B: 100명 중 25명 클릭
count = np.array([15, 25])  # 성공 횟수
nobs = np.array([100, 100])  # 전체 시도 횟수

z_stat, p_value = proportions_ztest(count, nobs)
print(f"z값 = {z_stat:.3f}, p값 = {p_value:.3f}")
# Out:
# z값 = -1.768, p값 = 0.077

# %%
from scipy.stats import f_oneway

# 세 그룹의 점수
group1 = [80, 85, 90]
group2 = [70, 75, 78]
group3 = [60, 65, 62]

f_stat, p_value = f_oneway(group1, group2, group3)
print(f"F값: {f_stat:.2f}, p값: {p_value:.4f}")
# Out:
# F값: 24.28, p값: 0.0013

# %%
import numpy as np
obs = np.array([[40, 10],  # 남자 (좋아함, 안좋아함) 교차표
                [30, 20]]) # 여자

chi2, p, dof, expected = stats.chi2_contingency(obs)
print(f"chi2 = {chi2:.3f}, p값 = {p:.3f}")
# Out:
# chi2 = 3.857, p값 = 0.050

# %%
import pandas as pd
from scipy import stats

# 1. 데이터 준비 (상황 가정)
# A그룹(파란 버튼): 평균 구매금액 50,000원
group_a = [50000, 48000, 52000, 49000, 51000, 47000, 53000, 50000, 49000, 51000]
# B그룹(빨간 버튼): 평균 구매금액 55,000원 (상승한 것처럼 보임)
group_b = [56000, 54000, 58000, 55000, 57000, 53000, 59000, 56000, 55000, 57000]

# 2. 도구 선택 및 분석: 독립 표본 T-test (서로 다른 고객군)
t_stat, p_val = stats.ttest_ind(group_b, group_a, alternative='greater')

# 3. 결과 해석
print(f"=== 실습 1: A/B 테스트 결과 ===")
print(f"P-value: {p_val:.5f}")

if p_val < 0.05:
    print(">> 결론: B안(빨간 버튼)이 통계적으로 유의미하게 더 높은 성과를 냅니다.")
    print(">> 제안: 전사적으로 빨간 버튼을 도입하십시오.")
else:
    print(">> 결론: 성과 차이는 우연일 가능성이 높습니다.")
    print(">> 제안: 버튼 색상 변경 보류.")
# Out:
# === 실습 1: A/B 테스트 결과 ===
# P-value: 0.00000
# >> 결론: B안(빨간 버튼)이 통계적으로 유의미하게 더 높은 성과를 냅니다.
# >> 제안: 전사적으로 빨간 버튼을 도입하십시오.

# %%
# 1. 데이터 준비 (동일인 10명의 교육 전후 데이터)
# 교육 전 시간 (오래 걸림)
time_before = [120, 110, 130, 140, 115, 125, 135, 110, 145, 120]
# 교육 후 시간 (단축됨)
time_after  = [90, 95, 100, 110, 85, 95, 105, 90, 115, 95]

# 2. 도구 선택 및 분석: 대응 표본 T-test (Paired T-test)
# "교육 후(After)가 전(Before)보다 시간이 '적게(less)' 걸리는가?"
t_stat, p_val = stats.ttest_rel(time_after, time_before, alternative='less')

# 3. 결과 해석
print(f"\n=== 실습 2: 교육 전후 비교 결과 ===")
print(f"P-value: {p_val:.5f}")

if p_val < 0.05:
    print(">> 결론: 교육 후 업무 시간이 통계적으로 유의미하게 감소했습니다.")
    print(">> 제안: 이 교육 커리큘럼을 전 직원 대상으로 확대하십시오.")
else:
    print(">> 결론: 교육의 효과가 명확하지 않습니다.")
# Out:
# === 실습 2: 교육 전후 비교 결과 ===
# P-value: 0.00000
# >> 결론: 교육 후 업무 시간이 통계적으로 유의미하게 감소했습니다.
# >> 제안: 이 교육 커리큘럼을 전 직원 대상으로 확대하십시오.
